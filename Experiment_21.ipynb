# %% [markdown]
# <a href="https://colab.research.google.com/github/11239a008-png/Compiler-Design-Lab/blob/main/Experiment_21.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Install (only once per session)
# !pip install ply

import ply.lex as lex
import ply.yacc as yacc
import sys

# Fix for Jupyter
__file__ = "parser.py"

# Remove old parsetab (important)
if 'parsetab' in sys.modules:
    del sys.modules['parsetab']

# -------- LEX --------
tokens = ('NUMBER',)

def t_NUMBER(t):
    r'\d+'
    t.value = int(t.value)
    return t

t_ignore = ' \t\n'

def t_error(t):
    t.lexer.skip(1)

lexer = lex.lex()

# -------- YACC --------
def p_expr(p):
    'expr : NUMBER'
    n = p[1]
    print("Even" if n % 2 == 0 else "Odd")

def p_error(p):
    print("Syntax error")

# Fix for Jupyter
parser = yacc.yacc(write_tables=False, debug=False)

# -------- RUN --------
parser.parse("24")   # change number here
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.6/49.6 kB 1.2 MB/s eta 0:00:00
# ...
# Even
